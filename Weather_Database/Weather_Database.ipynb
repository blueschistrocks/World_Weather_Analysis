# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key
plt.style.use('default')

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_wind_d = city_weather["wind"]["deg"]
        city_W_description = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #city_sunrise = datetime.utcfromtimestamp(city_weather["sys"]['sunrise']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Wind Direction": city_wind_d,
                          "Weather": city_W_description,
                          "Country": city_country,
                          "Date": city_date,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | rikitea
# Processing Record 2 of Set 16 | mar del plata
# Processing Record 3 of Set 16 | puerto ayora
# Processing Record 4 of Set 16 | port alfred
# Processing Record 5 of Set 16 | kapaa
# Processing Record 6 of Set 16 | westport
# Processing Record 7 of Set 16 | sitka
# Processing Record 8 of Set 16 | muyezerskiy
# Processing Record 9 of Set 16 | sasni
# Processing Record 10 of Set 16 | rio grande
# Processing Record 11 of Set 16 | cap malheureux
# Processing Record 12 of Set 16 | albany
# Processing Record 13 of Set 16 | varnamo
# Processing Record 14 of Set 16 | margate
# Processing Record 15 of Set 16 | punta arenas
# Processing Record 16 of Set 16 | torbay
# Processing Record 17 of Set 16 | cape town
# Processing Record 18 of Set 16 | hermanus
# Processing Record 19 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 16 | comodoro rivadavia
# Processing Record 21 of Set 16 | korla
# Processing Record 22 of Set 16 | jamestown
# Processing Record 23 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 16 | dikson
# Processing Record 25 of Set 16 | xining
# Processing Record 26 of Set 16 | pangnirtung
# Processing Record 27 of Set 16 | vestmannaeyjar
# Processing Record 28 of Set 16 | ust-kuyga
# Processing Record 29 of Set 16 | kodiak
# Processing Record 30 of Set 16 | vaini
# Processing Record 31 of Set 16 | sayat
# Processing Record 32 of Set 16 | grindavik
# Processing Record 33 of Set 16 | yellowknife
# Processing Record 34 of Set 16 | bluff
# Processing Record 35 of Set 16 | cherskiy
# Processing Record 36 of Set 16 | cooma
# Processing Record 37 of Set 16 | atlantis
# Processing Record 38 of Set 16 | bambous virieux
# Processing Record 39 of Set 16 | shenjiamen
# Processing Record 40 of Set 16 | touros
# Processing Record 41 of Set 16 | busselton
# Processing Record 42 of Set 16 | kumluca
# Processing Record 43 of Set 16 | clyde river
# Processing Record 44 of Set 16 | srednekolymsk
# Processing Record 45 of Set 16 | hasaki
# Processing Record 46 of Set 16 | balabac
# Processing Record 47 of Set 16 | tazovskiy
# Processing Record 48 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 16 | kollam
# Processing Record 50 of Set 16 | upernavik
# Processing Record 1 of Set 17 | freeport
# Processing Record 2 of Set 17 | guerrero negro
# Processing Record 3 of Set 17 | tonantins
# Processing Record 4 of Set 17 | atbasar
# Processing Record 5 of Set 17 | ushuaia
# Processing Record 6 of Set 17 | thompson
# Processing Record 7 of Set 17 | klaksvik
# Processing Record 8 of Set 17 | bethel
# Processing Record 9 of Set 17 | makakilo city
# Processing Record 10 of Set 17 | mataura
# Processing Record 11 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 17 | arraial do cabo
# Processing Record 13 of Set 17 | mayo
# Processing Record 14 of Set 17 | mount isa
# Processing Record 15 of Set 17 | kirkwall
# Processing Record 16 of Set 17 | georgetown
# Processing Record 17 of Set 17 | alofi
# Processing Record 18 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 17 | namatanai
# Processing Record 20 of Set 17 | qaanaaq
# Processing Record 21 of Set 17 | port lincoln
# Processing Record 22 of Set 17 | hobart
# Processing Record 23 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 17 | antropovo
# Processing Record 25 of Set 17 | saint-philippe
# Processing Record 26 of Set 17 | gitega
# Processing Record 27 of Set 17 | kasempa
# Processing Record 28 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 17 | barrow
# Processing Record 30 of Set 17 | zhizdra
# Processing Record 31 of Set 17 | omboue
# Processing Record 32 of Set 17 | carmo do paranaiba
# Processing Record 33 of Set 17 | toftir
# City not found. Skipping...
# Processing Record 34 of Set 17 | takhtamygda
# Processing Record 35 of Set 17 | saldanha
# Processing Record 36 of Set 17 | lebu
# Processing Record 37 of Set 17 | longyearbyen
# Processing Record 38 of Set 17 | palmer
# Processing Record 39 of Set 17 | teya
# Processing Record 40 of Set 17 | cidreira
# Processing Record 41 of Set 17 | bugko
# Processing Record 42 of Set 17 | abu samrah
# Processing Record 43 of Set 17 | butaritari
# Processing Record 44 of Set 17 | new norfolk
# Processing Record 45 of Set 17 | altamira
# Processing Record 46 of Set 17 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 17 | kavaratti
# Processing Record 48 of Set 17 | hay river
# Processing Record 49 of Set 17 | tuktoyaktuk
# Processing Record 50 of Set 17 | nikolskoye
# Processing Record 1 of Set 18 | laguna
# Processing Record 2 of Set 18 | houma
# Processing Record 3 of Set 18 | namibe
# Processing Record 4 of Set 18 | oneonta
# Processing Record 5 of Set 18 | harnosand
# Processing Record 6 of Set 18 | flinders
# Processing Record 7 of Set 18 | rocha
# Processing Record 8 of Set 18 | bonthe
# Processing Record 9 of Set 18 | lata
# Processing Record 10 of Set 18 | tura
# Processing Record 11 of Set 18 | khandagayty
# Processing Record 12 of Set 18 | biak
# Processing Record 13 of Set 18 | brattvag
# Processing Record 14 of Set 18 | rameshki
# Processing Record 15 of Set 18 | alice springs
# Processing Record 16 of Set 18 | capinopolis
# Processing Record 17 of Set 18 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 18 | hovd
# Processing Record 19 of Set 18 | aksay
# Processing Record 20 of Set 18 | tomigusuku
# Processing Record 21 of Set 18 | grand gaube
# Processing Record 22 of Set 18 | cairns
# Processing Record 23 of Set 18 | mamakan
# Processing Record 24 of Set 18 | ambulu
# Processing Record 25 of Set 18 | broome
# Processing Record 26 of Set 18 | pacific grove
# Processing Record 27 of Set 18 | provideniya
# Processing Record 28 of Set 18 | poum
# Processing Record 29 of Set 18 | mezen
# Processing Record 30 of Set 18 | nishihara
# Processing Record 31 of Set 18 | bulgan
# Processing Record 32 of Set 18 | half moon bay
# Processing Record 33 of Set 18 | caxito
# Processing Record 34 of Set 18 | naze
# Processing Record 35 of Set 18 | nouadhibou
# Processing Record 36 of Set 18 | soe
# Processing Record 37 of Set 18 | morros
# Processing Record 38 of Set 18 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 18 | hami
# Processing Record 40 of Set 18 | hilo
# Processing Record 41 of Set 18 | mahebourg
# Processing Record 42 of Set 18 | port hardy
# Processing Record 43 of Set 18 | hithadhoo
# Processing Record 44 of Set 18 | antalaha
# Processing Record 45 of Set 18 | bredasdorp
# Processing Record 46 of Set 18 | muravlenko
# Processing Record 47 of Set 18 | ballina
# Processing Record 48 of Set 18 | colares
# Processing Record 49 of Set 18 | san juan
# Processing Record 50 of Set 18 | aklavik
# Processing Record 1 of Set 19 | amapa
# Processing Record 2 of Set 19 | kabanjahe
# Processing Record 3 of Set 19 | nemuro
# Processing Record 4 of Set 19 | atuona
# Processing Record 5 of Set 19 | sao joao da barra
# Processing Record 6 of Set 19 | mansa
# Processing Record 7 of Set 19 | shetpe
# Processing Record 8 of Set 19 | hofn
# Processing Record 9 of Set 19 | port-gentil
# Processing Record 10 of Set 19 | kaitangata
# Processing Record 11 of Set 19 | lavrentiya
# Processing Record 12 of Set 19 | yola
# Processing Record 13 of Set 19 | saskylakh
# Processing Record 14 of Set 19 | ishim
# Processing Record 15 of Set 19 | salalah
# Processing Record 16 of Set 19 | tuatapere
# Processing Record 17 of Set 19 | port elizabeth
# Processing Record 18 of Set 19 | saint george
# Processing Record 19 of Set 19 | lompoc
# Processing Record 20 of Set 19 | bandarbeyla
# Processing Record 21 of Set 19 | erzin
# Processing Record 22 of Set 19 | inhambane
# Processing Record 23 of Set 19 | batticaloa
# Processing Record 24 of Set 19 | quelimane
# Processing Record 25 of Set 19 | ozernovskiy
# Processing Record 26 of Set 19 | beringovskiy
# Processing Record 27 of Set 19 | kieta
# Processing Record 28 of Set 19 | isangel
# Processing Record 29 of Set 19 | tallahassee
# Processing Record 30 of Set 19 | camopi
# Processing Record 31 of Set 19 | kudahuvadhoo
# Processing Record 32 of Set 19 | chuy
# Processing Record 33 of Set 19 | iqaluit
# Processing Record 34 of Set 19 | ribeira grande
# Processing Record 35 of Set 19 | paamiut
# Processing Record 36 of Set 19 | esperance
# Processing Record 37 of Set 19 | olga
# Processing Record 38 of Set 19 | kashan
# Processing Record 39 of Set 19 | ajdabiya
# Processing Record 40 of Set 19 | fortuna
# Processing Record 41 of Set 19 | tiksi
# Processing Record 42 of Set 19 | kurumkan
# Processing Record 43 of Set 19 | san pedro
# Processing Record 44 of Set 19 | airai
# Processing Record 45 of Set 19 | victoria
# Processing Record 46 of Set 19 | sikonge
# Processing Record 47 of Set 19 | birao
# Processing Record 48 of Set 19 | porto belo
# Processing Record 49 of Set 19 | tasiilaq
# Processing Record 50 of Set 19 | emirdag
# Processing Record 1 of Set 20 | manjakandriana
# Processing Record 2 of Set 20 | chilakalurupet
# Processing Record 3 of Set 20 | oktyabrskiy
# Processing Record 4 of Set 20 | doka
# Processing Record 5 of Set 20 | ibipeba
# Processing Record 6 of Set 20 | khatanga
# Processing Record 7 of Set 20 | lekhovon
# City not found. Skipping...
# Processing Record 8 of Set 20 | constitucion
# Processing Record 9 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 20 | jinchang
# Processing Record 11 of Set 20 | raudeberg
# Processing Record 12 of Set 20 | quatre cocos
# Processing Record 13 of Set 20 | chaiyo
# Processing Record 14 of Set 20 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 20 | miyazu
# Processing Record 16 of Set 20 | ginda
# Processing Record 17 of Set 20 | praia da vitoria
# Processing Record 18 of Set 20 | east london
# Processing Record 19 of Set 20 | severo-kurilsk
# Processing Record 20 of Set 20 | riverton
# Processing Record 21 of Set 20 | sungairaya
# Processing Record 22 of Set 20 | trincomalee
# Processing Record 23 of Set 20 | fort-shevchenko
# Processing Record 24 of Set 20 | douentza
# Processing Record 25 of Set 20 | canavieiras
# Processing Record 26 of Set 20 | dunedin
# Processing Record 27 of Set 20 | nome
# Processing Record 28 of Set 20 | chlorakas
# Processing Record 29 of Set 20 | great yarmouth
# Processing Record 30 of Set 20 | leningradskiy
# Processing Record 31 of Set 20 | jalu
# Processing Record 32 of Set 20 | sonqor
# Processing Record 33 of Set 20 | matamoros
# Processing Record 34 of Set 20 | antas
# Processing Record 35 of Set 20 | haicheng
# Processing Record 36 of Set 20 | russell
# Processing Record 37 of Set 20 | cabedelo
# Processing Record 38 of Set 20 | dzaoudzi
# Processing Record 39 of Set 20 | luderitz
# Processing Record 40 of Set 20 | geraldton
# Processing Record 41 of Set 20 | peruibe
# Processing Record 42 of Set 20 | uchaly
# Processing Record 43 of Set 20 | chicama
# Processing Record 44 of Set 20 | okhotsk
# Processing Record 45 of Set 20 | tambacounda
# Processing Record 46 of Set 20 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 20 | blairmore
# Processing Record 48 of Set 20 | salinopolis
# Processing Record 49 of Set 20 | bengkulu
# Processing Record 50 of Set 20 | norman wells
# Processing Record 1 of Set 21 | guamal
# Processing Record 2 of Set 21 | belaya gora
# Processing Record 3 of Set 21 | coihaique
# Processing Record 4 of Set 21 | kirakira
# Processing Record 5 of Set 21 | kavieng
# Processing Record 6 of Set 21 | san patricio
# Processing Record 7 of Set 21 | goderich
# Processing Record 8 of Set 21 | zhigansk
# Processing Record 9 of Set 21 | almeirim
# Processing Record 10 of Set 21 | lamu
# Processing Record 11 of Set 21 | jijiga
# Processing Record 12 of Set 21 | keighley
# Processing Record 13 of Set 21 | samarai
# Processing Record 14 of Set 21 | carnarvon
# Processing Record 15 of Set 21 | okahandja
# Processing Record 16 of Set 21 | salamanca
# Processing Record 17 of Set 21 | atikokan
# Processing Record 18 of Set 21 | zhigalovo
# Processing Record 19 of Set 21 | souillac
# Processing Record 20 of Set 21 | lorengau
# Processing Record 21 of Set 21 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 21 | urengoy
# Processing Record 23 of Set 21 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 21 | santa marta
# Processing Record 25 of Set 21 | faanui
# Processing Record 26 of Set 21 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 21 | kizukuri
# Processing Record 28 of Set 21 | saryg-sep
# Processing Record 29 of Set 21 | faya
# Processing Record 30 of Set 21 | codrington
# Processing Record 31 of Set 21 | tilichiki
# Processing Record 32 of Set 21 | castro
# Processing Record 33 of Set 21 | opuwo
# Processing Record 34 of Set 21 | avarua
# Processing Record 35 of Set 21 | anloga
# Processing Record 36 of Set 21 | touba
# Processing Record 37 of Set 21 | husavik
# Processing Record 38 of Set 21 | monkey bay
# Processing Record 39 of Set 21 | warren
# Processing Record 40 of Set 21 | port-cartier
# Processing Record 41 of Set 21 | sharanga
# Processing Record 42 of Set 21 | yomou
# Processing Record 43 of Set 21 | edeia
# Processing Record 44 of Set 21 | ambilobe
# Processing Record 45 of Set 21 | jalingo
# Processing Record 46 of Set 21 | rognan
# Processing Record 47 of Set 21 | miri
# Processing Record 48 of Set 21 | ilulissat
# Processing Record 49 of Set 21 | sola
# Processing Record 50 of Set 21 | cuenca
# Processing Record 1 of Set 22 | santo antonio da platina
# Processing Record 2 of Set 22 | virginia beach
# Processing Record 3 of Set 22 | portland
# Processing Record 4 of Set 22 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 22 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 22 | asfi
# Processing Record 7 of Set 22 | carson city
# Processing Record 8 of Set 22 | ust-tsilma
# Processing Record 9 of Set 22 | makhinjauri
# Processing Record 10 of Set 22 | maceio
# Processing Record 11 of Set 22 | almenara
# Processing Record 12 of Set 22 | hambantota
# Processing Record 13 of Set 22 | the pas
# Processing Record 14 of Set 22 | detroit
# Processing Record 15 of Set 22 | coquimbo
# Processing Record 16 of Set 22 | bathsheba
# Processing Record 17 of Set 22 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 22 | cabo san lucas
# Processing Record 19 of Set 22 | moose factory
# Processing Record 20 of Set 22 | phan thiet
# Processing Record 21 of Set 22 | venice
# Processing Record 22 of Set 22 | luba
# Processing Record 23 of Set 22 | meadow lake
# Processing Record 24 of Set 22 | cockburn town
# Processing Record 25 of Set 22 | kalmunai
# Processing Record 26 of Set 22 | ancud
# Processing Record 27 of Set 22 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 22 | tetouan
# Processing Record 29 of Set 22 | fairbanks
# Processing Record 30 of Set 22 | puerto narino
# Processing Record 31 of Set 22 | anadyr
# Processing Record 32 of Set 22 | port keats
# Processing Record 33 of Set 22 | najran
# Processing Record 34 of Set 22 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 22 | hervey bay
# Processing Record 36 of Set 22 | cuyo
# Processing Record 37 of Set 22 | sabang
# Processing Record 38 of Set 22 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 22 | smithers
# Processing Record 40 of Set 22 | haines junction
# Processing Record 41 of Set 22 | tynda
# Processing Record 42 of Set 22 | temaraia
# City not found. Skipping...
# Processing Record 43 of Set 22 | nanortalik
# Processing Record 44 of Set 22 | bandar-e lengeh
# Processing Record 45 of Set 22 | vardo
# Processing Record 46 of Set 22 | linxia
# Processing Record 47 of Set 22 | awjilah
# Processing Record 48 of Set 22 | padang
# Processing Record 49 of Set 22 | kloulklubed
# Processing Record 50 of Set 22 | deputatskiy
# Processing Record 1 of Set 23 | mustasaari
# Processing Record 2 of Set 23 | zhuozhou
# City not found. Skipping...
# Processing Record 3 of Set 23 | ponta do sol
# Processing Record 4 of Set 23 | yulara
# Processing Record 5 of Set 23 | karratha
# Processing Record 6 of Set 23 | sesheke
# Processing Record 7 of Set 23 | auki
# Processing Record 8 of Set 23 | stranda
# Processing Record 9 of Set 23 | paita
# Processing Record 10 of Set 23 | honiara
# Processing Record 11 of Set 23 | narsaq
# Processing Record 12 of Set 23 | pedernales
# Processing Record 13 of Set 23 | fare
# Processing Record 14 of Set 23 | hue
# Processing Record 15 of Set 23 | mitsamiouli
# Processing Record 16 of Set 23 | ponta delgada
# Processing Record 17 of Set 23 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 23 | necochea
# Processing Record 19 of Set 23 | dustlik
# Processing Record 20 of Set 23 | la palma
# Processing Record 21 of Set 23 | omsukchan
# Processing Record 22 of Set 23 | pisco
# Processing Record 23 of Set 23 | marrakesh
# Processing Record 24 of Set 23 | malanje
# Processing Record 25 of Set 23 | havre-saint-pierre
# Processing Record 26 of Set 23 | ostrov
# Processing Record 27 of Set 23 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 23 | yar-sale
# Processing Record 29 of Set 23 | rincon
# Processing Record 30 of Set 23 | varkkallai
# Processing Record 31 of Set 23 | shimoda
# Processing Record 32 of Set 23 | zyryanka
# Processing Record 33 of Set 23 | kaupanger
# Processing Record 34 of Set 23 | bam
# Processing Record 35 of Set 23 | cayenne
# Processing Record 36 of Set 23 | urumqi
# Processing Record 37 of Set 23 | idenao
# Processing Record 38 of Set 23 | mount gambier
# Processing Record 39 of Set 23 | komsomolskiy
# Processing Record 40 of Set 23 | pevek
# Processing Record 41 of Set 23 | teeli
# Processing Record 42 of Set 23 | turayf
# Processing Record 43 of Set 23 | rehoboth
# Processing Record 44 of Set 23 | la paz
# Processing Record 45 of Set 23 | east wenatchee bench
# Processing Record 46 of Set 23 | okato
# Processing Record 47 of Set 23 | ankpa
# Processing Record 48 of Set 23 | merauke
# Processing Record 49 of Set 23 | okha
# Processing Record 50 of Set 23 | kurchum
# Processing Record 1 of Set 24 | hammerfest
# Processing Record 2 of Set 24 | lakatoro
# Processing Record 3 of Set 24 | veraval
# Processing Record 4 of Set 24 | banjarmasin
# Processing Record 5 of Set 24 | the valley
# Processing Record 6 of Set 24 | broken hill
# Processing Record 7 of Set 24 | vila franca do campo
# Processing Record 8 of Set 24 | fort nelson
# Processing Record 9 of Set 24 | shanghai
# Processing Record 10 of Set 24 | achisay
# City not found. Skipping...
# Processing Record 11 of Set 24 | miyako
# Processing Record 12 of Set 24 | capaci
# Processing Record 13 of Set 24 | vao
# Processing Record 14 of Set 24 | gravdal
# Processing Record 15 of Set 24 | midland
# Processing Record 16 of Set 24 | thinadhoo
# Processing Record 17 of Set 24 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 24 | porto santo
# Processing Record 19 of Set 24 | orotukan
# Processing Record 20 of Set 24 | azimur
# City not found. Skipping...
# Processing Record 21 of Set 24 | inuvik
# Processing Record 22 of Set 24 | tucuma
# Processing Record 23 of Set 24 | yeppoon
# Processing Record 24 of Set 24 | kruisfontein
# Processing Record 25 of Set 24 | cagdianao
# Processing Record 26 of Set 24 | vagur
# Processing Record 27 of Set 24 | burica
# City not found. Skipping...
# Processing Record 28 of Set 24 | lagoa
# Processing Record 29 of Set 24 | puerto escondido
# Processing Record 30 of Set 24 | chapais
# Processing Record 31 of Set 24 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 24 | muroto
# Processing Record 33 of Set 24 | badaojiang
# City not found. Skipping...
# Processing Record 34 of Set 24 | methven
# Processing Record 35 of Set 24 | pandan
# Processing Record 36 of Set 24 | crixas
# Processing Record 37 of Set 24 | nikki
# Processing Record 38 of Set 24 | mareeba
# Processing Record 39 of Set 24 | vacaria
# Processing Record 40 of Set 24 | marawi
# Processing Record 41 of Set 24 | awbari
# Processing Record 42 of Set 24 | sal rei
# Processing Record 43 of Set 24 | chardara
# Processing Record 44 of Set 24 | yanchukan
# City not found. Skipping...
# Processing Record 45 of Set 24 | ninghai
# Processing Record 46 of Set 24 | marinette
# Processing Record 47 of Set 24 | muncar
# Processing Record 48 of Set 24 | cururupu
# Processing Record 49 of Set 24 | tukrah
# Processing Record 50 of Set 24 | kisaran
# Processing Record 1 of Set 25 | zabaykalsk
# Processing Record 2 of Set 25 | moses lake
# Processing Record 3 of Set 25 | henties bay
# Processing Record 4 of Set 25 | chokurdakh
# Processing Record 5 of Set 25 | tual
# Processing Record 6 of Set 25 | sciacca
# Processing Record 7 of Set 25 | barabinsk
# Processing Record 8 of Set 25 | asau
# Processing Record 9 of Set 25 | olafsvik
# Processing Record 10 of Set 25 | ahuimanu
# Processing Record 11 of Set 25 | makung
# City not found. Skipping...
# Processing Record 12 of Set 25 | adrar
# Processing Record 13 of Set 25 | la asuncion
# Processing Record 14 of Set 25 | rock sound
# Processing Record 15 of Set 25 | zheleznogorsk
# Processing Record 16 of Set 25 | ambon
# Processing Record 17 of Set 25 | malinovskiy
# Processing Record 18 of Set 25 | escanaba
# Processing Record 19 of Set 25 | bestobe
# Processing Record 20 of Set 25 | belem de sao francisco
# Processing Record 21 of Set 25 | udachnyy
# Processing Record 22 of Set 25 | dawei
# Processing Record 23 of Set 25 | wilmington
# Processing Record 24 of Set 25 | yerbogachen
# Processing Record 25 of Set 25 | idappadi
# Processing Record 26 of Set 25 | batagay-alyta
# Processing Record 27 of Set 25 | marovoay
# Processing Record 28 of Set 25 | rawson
# Processing Record 29 of Set 25 | svetlogorsk
# Processing Record 30 of Set 25 | seoul
# Processing Record 31 of Set 25 | hatillo
# Processing Record 32 of Set 25 | prince rupert
# Processing Record 33 of Set 25 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 25 | bajos de haina
# Processing Record 35 of Set 25 | hamilton
# Processing Record 36 of Set 25 | ixtapa
# Processing Record 37 of Set 25 | bayangol
# Processing Record 38 of Set 25 | puerto carreno
# Processing Record 39 of Set 25 | lobito
# Processing Record 40 of Set 25 | vincennes
# Processing Record 41 of Set 25 | semey
# Processing Record 42 of Set 25 | ayagoz
# Processing Record 43 of Set 25 | angoche
# Processing Record 44 of Set 25 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 25 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 25 | tessalit
# Processing Record 47 of Set 25 | nara
# Processing Record 48 of Set 25 | reyes
# Processing Record 49 of Set 25 | bonfim
# Processing Record 50 of Set 25 | hohoe
# Processing Record 1 of Set 26 | coihueco
# Processing Record 2 of Set 26 | viedma
# Processing Record 3 of Set 26 | manbij
# Processing Record 4 of Set 26 | waw
# Processing Record 5 of Set 26 | raga
# Processing Record 6 of Set 26 | dillon
# Processing Record 7 of Set 26 | igarapava
# Processing Record 8 of Set 26 | aykhal
# Processing Record 9 of Set 26 | fort saint john
# City not found. Skipping...
# Processing Record 10 of Set 26 | harper
# Processing Record 11 of Set 26 | turukhansk
# Processing Record 12 of Set 26 | otradnoye
# Processing Record 13 of Set 26 | kungurtug
# Processing Record 14 of Set 26 | nadadores
# Processing Record 15 of Set 26 | noshiro
# Processing Record 16 of Set 26 | sibolga
# Processing Record 17 of Set 26 | san andres
# Processing Record 18 of Set 26 | balsas
# Processing Record 19 of Set 26 | baracoa
# Processing Record 20 of Set 26 | ankazobe
# Processing Record 21 of Set 26 | bom jesus da lapa
# Processing Record 22 of Set 26 | saint-augustin
# Processing Record 23 of Set 26 | chara
# Processing Record 24 of Set 26 | balikpapan
# Processing Record 25 of Set 26 | gambela
# Processing Record 26 of Set 26 | sao filipe
# Processing Record 27 of Set 26 | pishin
# Processing Record 28 of Set 26 | ugoofaaru
# Processing Record 29 of Set 26 | port macquarie
# Processing Record 30 of Set 26 | grants pass
# Processing Record 31 of Set 26 | luis correia
# Processing Record 32 of Set 26 | tucumcari
# Processing Record 33 of Set 26 | filingue
# Processing Record 34 of Set 26 | palu
# Processing Record 35 of Set 26 | churapcha
# Processing Record 36 of Set 26 | astana
# Processing Record 37 of Set 26 | acarau
# Processing Record 38 of Set 26 | valle hermoso
# Processing Record 39 of Set 26 | san jeronimo
# Processing Record 40 of Set 26 | mbarara
# Processing Record 41 of Set 26 | taggia
# Processing Record 42 of Set 26 | bangolo
# Processing Record 43 of Set 26 | abaza
# Processing Record 44 of Set 26 | busko-zdroj
# Processing Record 45 of Set 26 | kuvandyk
# Processing Record 46 of Set 26 | farah
# Processing Record 47 of Set 26 | guilin
# Processing Record 48 of Set 26 | high level
# Processing Record 49 of Set 26 | carndonagh
# Processing Record 50 of Set 26 | kozhevnikovo
# Processing Record 1 of Set 27 | yumen
# Processing Record 2 of Set 27 | dingle
# Processing Record 3 of Set 27 | ibra
# Processing Record 4 of Set 27 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 27 | conde
# Processing Record 6 of Set 27 | dwarka
# Processing Record 7 of Set 27 | dzhebariki-khaya
# Processing Record 8 of Set 27 | copiapo
# Processing Record 9 of Set 27 | mananjary
# Processing Record 10 of Set 27 | thunder bay
# Processing Record 11 of Set 27 | sakakah
# Processing Record 12 of Set 27 | sept-iles
# Processing Record 13 of Set 27 | kamenka
# Processing Record 14 of Set 27 | kotido
# Processing Record 15 of Set 27 | santiago
# Processing Record 16 of Set 27 | tsaratanana
# Processing Record 17 of Set 27 | clearlake
# Processing Record 18 of Set 27 | mayumba
# Processing Record 19 of Set 27 | borba
# Processing Record 20 of Set 27 | paso de los toros
# Processing Record 21 of Set 27 | calama
# Processing Record 22 of Set 27 | tsagan aman
# Processing Record 23 of Set 27 | lake charles
# Processing Record 24 of Set 27 | verkhoyansk
# Processing Record 25 of Set 27 | kununurra
# Processing Record 26 of Set 27 | korem
# Processing Record 27 of Set 27 | shizukuishi
# Processing Record 28 of Set 27 | toora-khem
# Processing Record 29 of Set 27 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 27 | contamana
# Processing Record 31 of Set 27 | kysyl-syr
# Processing Record 32 of Set 27 | akhisar
# Processing Record 33 of Set 27 | itoman
# Processing Record 34 of Set 27 | senno
# Processing Record 35 of Set 27 | aviles
# Processing Record 36 of Set 27 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 27 | whitehorse
# Processing Record 38 of Set 27 | carauari
# Processing Record 39 of Set 27 | blankenberge
# Processing Record 40 of Set 27 | talnakh
# Processing Record 41 of Set 27 | yibin
# Processing Record 42 of Set 27 | vestmanna
# Processing Record 43 of Set 27 | dhidhdhoo
# Processing Record 44 of Set 27 | marsh harbour
# Processing Record 45 of Set 27 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 27 | izhma
# Processing Record 47 of Set 27 | lenti
# Processing Record 48 of Set 27 | sobolevo
# Processing Record 49 of Set 27 | ola
# Processing Record 50 of Set 27 | yaan
# Processing Record 1 of Set 28 | katsuura
# Processing Record 2 of Set 28 | zabol
# Processing Record 3 of Set 28 | elat
# Processing Record 4 of Set 28 | channel-port aux basques
# Processing Record 5 of Set 28 | wanning
# Processing Record 6 of Set 28 | oga
# Processing Record 7 of Set 28 | te anau
# Processing Record 8 of Set 28 | lohardaga
# Processing Record 9 of Set 28 | natal
# Processing Record 10 of Set 28 | genhe
# Processing Record 11 of Set 28 | scottsbluff
# Processing Record 12 of Set 28 | puquio
# Processing Record 13 of Set 28 | stokmarknes
# Processing Record 14 of Set 28 | samfya
# Processing Record 15 of Set 28 | niquero
# Processing Record 16 of Set 28 | drochia
# Processing Record 17 of Set 28 | buin
# Processing Record 18 of Set 28 | sur
# Processing Record 19 of Set 28 | camapua
# Processing Record 20 of Set 28 | amahai
# Processing Record 21 of Set 28 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 28 | port blair
# Processing Record 23 of Set 28 | kurilsk
# Processing Record 24 of Set 28 | vanimo
# Processing Record 25 of Set 28 | porosozero
# Processing Record 26 of Set 28 | jiuquan
# Processing Record 27 of Set 28 | menongue
# Processing Record 28 of Set 28 | panguna
# Processing Record 29 of Set 28 | rawah
# Processing Record 30 of Set 28 | rio verde de mato grosso
# Processing Record 31 of Set 28 | kushikino
# Processing Record 32 of Set 28 | qasigiannguit
# Processing Record 33 of Set 28 | shestakovo
# Processing Record 34 of Set 28 | dutse
# Processing Record 35 of Set 28 | axim
# Processing Record 36 of Set 28 | shepsi
# Processing Record 37 of Set 28 | belomorsk
# Processing Record 38 of Set 28 | sydney
# Processing Record 39 of Set 28 | at-bashi
# Processing Record 40 of Set 28 | peace river
# Processing Record 41 of Set 28 | karaman
# Processing Record 42 of Set 28 | gallup
# Processing Record 43 of Set 28 | shumskiy
# Processing Record 44 of Set 28 | kuminskiy
# Processing Record 45 of Set 28 | vila velha
# Processing Record 46 of Set 28 | muros
# Processing Record 47 of Set 28 | sambava
# Processing Record 48 of Set 28 | can tho
# Processing Record 49 of Set 28 | mendota
# Processing Record 50 of Set 28 | trinidad
# Processing Record 1 of Set 29 | bijie
# Processing Record 2 of Set 29 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 29 | alekseyevsk
# Processing Record 4 of Set 29 | cavalcante
# Processing Record 5 of Set 29 | poya
# Processing Record 6 of Set 29 | nokaneng
# Processing Record 7 of Set 29 | of
# City not found. Skipping...
# Processing Record 8 of Set 29 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 29 | khuzhir
# Processing Record 10 of Set 29 | tefe
# Processing Record 11 of Set 29 | cuitareo
# Processing Record 12 of Set 29 | pogranichnyy
# Processing Record 13 of Set 29 | mackenzie
# Processing Record 14 of Set 29 | amet
# Processing Record 15 of Set 29 | mnogovershinnyy
# Processing Record 16 of Set 29 | norwood
# Processing Record 17 of Set 29 | yelizovo
# Processing Record 18 of Set 29 | gornopravdinsk
# Processing Record 19 of Set 29 | ust-karsk
# Processing Record 20 of Set 29 | totness
# Processing Record 21 of Set 29 | itapolis
# Processing Record 22 of Set 29 | rawa mazowiecka
# Processing Record 23 of Set 29 | duldurga
# Processing Record 24 of Set 29 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 29 | castellammare del golfo
# Processing Record 26 of Set 29 | xuddur
# Processing Record 27 of Set 29 | oranjestad
# Processing Record 28 of Set 29 | sainte-marie
# Processing Record 29 of Set 29 | abu kamal
# Processing Record 30 of Set 29 | maraba
# Processing Record 31 of Set 29 | zhanakorgan
# Processing Record 32 of Set 29 | trairi
# Processing Record 33 of Set 29 | iringa
# Processing Record 34 of Set 29 | roald
# Processing Record 35 of Set 29 | boueni
# Processing Record 36 of Set 29 | jhargram
# Processing Record 37 of Set 29 | sorong
# Processing Record 38 of Set 29 | chimore
# Processing Record 39 of Set 29 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 29 | ornskoldsvik
# Processing Record 41 of Set 29 | warangal
# Processing Record 42 of Set 29 | imbituba
# Processing Record 43 of Set 29 | zhitikara
# City not found. Skipping...
# Processing Record 44 of Set 29 | rayong
# Processing Record 45 of Set 29 | srandakan
# Processing Record 46 of Set 29 | montemor-o-novo
# Processing Record 47 of Set 29 | tautira
# Processing Record 48 of Set 29 | atkinson
# Processing Record 49 of Set 29 | madimba
# Processing Record 50 of Set 29 | ostrovnoy
# Processing Record 1 of Set 30 | eldorado
# Processing Record 2 of Set 30 | araouane
# Processing Record 3 of Set 30 | ambodifototra
# City not found. Skipping...
# Processing Record 4 of Set 30 | dehui
# Processing Record 5 of Set 30 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 30 | ca mau
# Processing Record 7 of Set 30 | uribia
# Processing Record 8 of Set 30 | staffanstorp
# Processing Record 9 of Set 30 | agirish
# Processing Record 10 of Set 30 | alice town
# Processing Record 11 of Set 30 | goya
# Processing Record 12 of Set 30 | banda aceh
# Processing Record 13 of Set 30 | talara
# Processing Record 14 of Set 30 | nagua
# Processing Record 15 of Set 30 | bajil
# Processing Record 16 of Set 30 | harrison
# Processing Record 17 of Set 30 | yinchuan
# Processing Record 18 of Set 30 | iberia
# Processing Record 19 of Set 30 | kerki
# City not found. Skipping...
# Processing Record 20 of Set 30 | yuancheng
# Processing Record 21 of Set 30 | gannan
# Processing Record 22 of Set 30 | cartagena
# Processing Record 23 of Set 30 | gurskoye
# City not found. Skipping...
# Processing Record 24 of Set 30 | saurimo
# Processing Record 25 of Set 30 | monrovia
# Processing Record 26 of Set 30 | buraydah
# Processing Record 27 of Set 30 | cootamundra
# Processing Record 28 of Set 30 | boguchany
# Processing Record 29 of Set 30 | agadez
# Processing Record 30 of Set 30 | hermiston
# Processing Record 31 of Set 30 | alekseyevka
# Processing Record 32 of Set 30 | ahipara
# Processing Record 33 of Set 30 | muhos
# Processing Record 34 of Set 30 | egvekinot
# Processing Record 35 of Set 30 | port augusta
# Processing Record 36 of Set 30 | sarkand
# Processing Record 37 of Set 30 | taganak
# Processing Record 38 of Set 30 | thessalon
# Processing Record 39 of Set 30 | lasa
# Processing Record 40 of Set 30 | surgut
# Processing Record 41 of Set 30 | sokoni
# Processing Record 42 of Set 30 | angoram
# Processing Record 43 of Set 30 | kahului
# Processing Record 44 of Set 30 | durant
# Processing Record 45 of Set 30 | san cristobal
# Processing Record 46 of Set 30 | zabid
# Processing Record 47 of Set 30 | aguimes
# Processing Record 48 of Set 30 | tigil
# Processing Record 49 of Set 30 | olean
# Processing Record 50 of Set 30 | buriti
# Processing Record 1 of Set 31 | iranshahr
# Processing Record 2 of Set 31 | riyadh
# Processing Record 3 of Set 31 | catamarca
# Processing Record 4 of Set 31 | south lake tahoe
# Processing Record 5 of Set 31 | mikun
# Processing Record 6 of Set 31 | kaifeng
# Processing Record 7 of Set 31 | valenca
# Processing Record 8 of Set 31 | belyy yar
# Processing Record 9 of Set 31 | megion
# Processing Record 10 of Set 31 | wuchang
# Processing Record 11 of Set 31 | ilhabela
# Processing Record 12 of Set 31 | madaoua
# Processing Record 13 of Set 31 | richards bay
# Processing Record 14 of Set 31 | konevo
# Processing Record 15 of Set 31 | ijaki
# City not found. Skipping...
# Processing Record 16 of Set 31 | vanavara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea -23.1203 -134.9692     80.28        74          24
# 1    Mar Del Plata -38.0023  -57.5575     50.88        70           0
# 2     Puerto Ayora  -0.7393  -90.3518     77.88        80          24
# 3      Port Alfred -33.5906   26.8910     73.40        85         100
# 4            Kapaa  22.0752 -159.3190     78.78        75          40
# ..             ...      ...       ...       ...       ...         ...
# 705       Ilhabela -23.7781  -45.3581     78.08        79          65
# 706        Madaoua  14.0730    5.9600     70.45        10           5
# 707   Richards Bay -28.7830   32.0377     71.37        71          66
# 708         Konevo  62.1215   39.3192     27.73        94          37
# 709       Vanavara  60.3400  102.2797     19.54        85         100
#
#      Wind Speed  Wind Direction           Weather Country                 Date
# 0          9.44              30        few clouds      PF  2022-03-19 05:49:23
# 1          5.01             271         clear sky      AR  2022-03-19 05:49:24
# 2          4.81             158        few clouds      EC  2022-03-19 05:46:26
# 3          8.48              67   overcast clouds      ZA  2022-03-19 05:49:25
# 4         14.97              50  scattered clouds      US  2022-03-19 05:49:25
# ..          ...             ...               ...     ...                  ...
# 705        3.98               5     broken clouds      BR  2022-03-19 06:10:02
# 706       10.09              68         clear sky      NE  2022-03-19 06:10:02
# 707        4.41             351     broken clouds      ZA  2022-03-19 06:10:03
# 708        7.81             265  scattered clouds      RU  2022-03-19 06:10:03
# 709       12.12             244   overcast clouds      RU  2022-03-19 06:10:04
#
# [710 rows x 11 columns]

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
